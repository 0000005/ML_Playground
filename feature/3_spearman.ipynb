# %%
import pandas as pd

X = [[5], [8], [10], [12], [15], [3], [7], [9], [14], [6]]
y = [55, 65, 70, 75, 85, 50, 60, 72, 80, 58]

x = pd.DataFrame(X)
y = pd.Series(y)

print(x.shape)
print(y.shape)
# Out:
# (10, 1)
# (10,)

# %%
print(x.corrwith(y,method="spearman"))
# Out:
# 0    0.987879
# dtype: float64
