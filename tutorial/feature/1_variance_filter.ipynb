# %%
import numpy as np

# %%
# 生成标准的正太分布
a = np.random.randn(100)
print(np.var(a))
# Out:
# 0.9656901821531433

# %%
#生成指定参数的正态分布。
b = np.random.normal(5,0.1,size=100)
print(np.var(b))
# Out:
# 0.011161484142346623

# %%
# 构造特征向量，将两个向量合并为一个矩阵
X =np.vstack((a,b))
print(X.shape)
# 需要转置，将两行一百列转换为一百行两列。
X = X.T
print(X.shape)
# Out:
# (2, 100)
# (100, 2)

# %%
#过滤低方差的特征，这类特征意义不大。
from sklearn.feature_selection import VarianceThreshold
vt = VarianceThreshold(0.1)
X_filtered = vt.fit_transform(X)
print(X_filtered)
print(X_filtered.shape)
# Out:
# [[0.28059378021605175]
#  [-0.738871918048903]
#  [-0.6574283456394984]
#  [1.0696242909837643]
#  [-0.1684756631918089]
#  [0.19022440360945572]
#  [-0.4230591636445049]
#  [0.12909089849589778]
#  [0.34239593900915427]
#  [1.0968663443951583]
#  [2.8242826328944877]
#  [-0.6853913471142146]
#  [0.27049422180046817]
#  [1.5111252130970938]
#  [-0.8321098819483619]
#  [0.09243761545125241]
#  [-0.2917161910558923]
#  [1.628682990539497]
#  [-0.35249619631821066]
#  [-1.2310635843467657]
#  [1.286889258212657]
#  [-0.0931679727012572]
#  [-0.5538059115776856]
#  [-0.24347712025640195]
#  [-0.05449860686376505]
#  [-1.6342948614274275]
#  [0.6887439213538409]
#  [-0.20870616946228565]
#  [-2.127975655197007]
#  [0.14627555903275352]
#  [-1.4807376906625627]
#  [-1.6430086894319327]
#  [1.0663946010114733]
#  [2.0212651525472154]
#  [0.1903499079833166]
#  [1.7384824134890724]
#  [-0.7975762243640345]
#  [0.2976489487199]
#  [-0.6420665892346495]
#  [-0.8846480883982842]
#  [-1.438618599160564]
#  [0.06573976466997992]
#  [0.9472719055120862]
#  [-0.3349776867669989]
#  [1.6631509669677833]
#  [-0.9254995485162114]
#  [-0.6152169134316173]
#  [-0.2576184543023244]
#  [-0.7383364100452048]
#  [-0.550690184881136]
#  [1.0011178920020951]
#  [1.7118729295419968]
#  [-2.242573331765109]
#  [0.08759130331533256]
#  [2.1895109303805556]
#  [1.0671021104798866]
#  [-1.1343420002443316]
#  [-0.36885452822521503]
#  [1.1169371753360782]
#  [-0.691015342669157]
#  [0.18165290800611364]
#  [0.2906654808930057]
#  [0.5961887375135276]
#  [-0.16061221870227607]
#  [0.3219778996694441]
#  [-0.46097480112808437]
#  [-1.0894507870316366]
#  [-0.6367584980000632]
#  [-0.49667553345743853]
#  [0.3710568977985762]
#  [0.7901829052529238]
#  [-0.3035949300040523]
#  [0.021064997278194747]
#  [-0.9665315454506462]
#  [-1.8902593231358225]
#  [0.9674211262928278]
#  [-0.8729893765214687]
#  [-1.1867256233318808]
#  [0.8272410305759106]
#  [0.2723528544919609]
#  [0.48388253705708717]
#  [0.09542125147731934]
#  [0.15992454114386312]
#  [0.26049474935625677]
#  [-1.5299778225609515]
#  [-0.8917666548688016]
#  [0.723980601295569]
#  [0.4541479569919555]
#  [0.27273180167042566]
#  [-0.20386242652140493]
#  [0.49449546749084944]
#  [0.5807159708412459]
#  [-1.4736840626737109]
#  [1.626398076499785]
#  [1.448318243562778]
#  [-0.4053450528571323]
#  [-0.28826909064263695]
#  [1.061137828846796]
#  [0.560546013687803]
#  [-0.7847532681703513]]
# (100, 1)
